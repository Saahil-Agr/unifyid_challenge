# %%
import urllib.request as request
import json
import os
import pandas as pd
import datetime
import collections
import numpy as np

# %% [markdown]
# ## Algorithm explanation
# 1. The main feature extracted from the keystroke data for every entry for every user is the time elapsed to type the given key since the last uncorrected key. So if backspace is used, then the time elapsed in typping the erase char, backspace and the new char are all included in the typing time of the new char. The reason for using this is that it is one of the simplest way of encoding corrections at different chars through the typing time which should have some user specific distribution.
# 2. The next feature used is just the raw count of backspaces typed by the user in every attempt.

# %%
def validateFeaturizeData(data, user_id, colnames):
    valid_str = 'Be Authentic. Be Yourself. Be Typing.'
    feature_length = len(valid_str) + 1 # 1 for number of backspaces.
    user_feature_df = pd.DataFrame(columns = colnames)
    invalid_count = 0
    invalid_idx = []
    total_count = len(data)
#     if total_count < 300:
#         print('insufficient data for user {}'.format(user_id))
#         return None, ()
    for idx, typed_str in enumerate(data):
        processed_str = []
        prev_time_stamp = None
        backstrokes = 0
        user_features = []
        for char_dict in typed_str:
            curr_char = char_dict["character"]
            if curr_char == "[backspace]":
                processed_str.pop() # remove the last char
                user_features.pop() # remove the typing time corresponding to last char
                backstrokes += 1
            else:
                curr_time_stamp = datetime.datetime.strptime(char_dict['typed_at'], '%Y-%m-%dT%H:%M:%S.%f')
                if prev_time_stamp:
                    typing_time = (curr_time_stamp - prev_time_stamp).total_seconds()
                else:
                    typing_time = 0.0
                processed_str.append(curr_char)
                prev_time_stamp = curr_time_stamp
                user_features.append(typing_time)       
            
        
        filtered_str = ''.join(processed_str)
        if filtered_str == valid_str:
            # append it to the dataframe.
            user_features.append(backstrokes)
            if len(user_features) != feature_length:
                print('Mismatch in feature length for a valid string.\n\
The original string is {}.\n\
The processed string is {}.\n\
The number of backspaces are {}.\n\
User features list is {}'.format(typed_str, processed_str, backstrokes, user_features))
            
            else:
                user_feature_df = user_feature_df.append(pd.Series(user_features, index = colnames), ignore_index = True)
        else:
#             print('invalid string: '+filtered_str)# do nothing and pass
            invalid_count += 1
            invalid_idx.append(idx)
    
    user_feature_df['user_id'] = user_id        
#     print(user_feature_df)
#     print(user_id, total_count, invalid_count)
    return user_feature_df, (total_count, invalid_count), invalid_idx

# %% [markdown]
# ## Reading Train Data
#
# Code to read the input data from the provided urls, filter valid strings and hence enroll eligible users and featurize their typing data and convert it to a dataframe

# %%
domain = 'https://challenges.unify.id/v1/mle'
total_users = 0
next_user = 'user_4a438fdede4e11e9b986acde48001122.json'
url_error = 0
stats = collections.defaultdict(list)
unenrolled_users = []
no_features = len('Be Authentic. Be Yourself. Be Typing.')
col_names = ['f_{}'.format(i) for i in range(1, no_features+1)]
col_names += ['del', 'user_id']
train_data = pd.DataFrame(columns = col_names)
while next_user:
    url = os.path.join(domain, next_user)
    with request.urlopen(url) as response:
            if response.getcode() == 200:
                source = response.read()
                data = json.loads(source)
                total_users += 1
                user_df, user_stats, _ = validateFeaturizeData(data['user_data'], next_user, col_names[:-1])
                if user_stats[0] - user_stats[1] >= 300:
                    stats['user'].append(next_user)
                    stats['total_count'].append(user_stats[0])
                    stats['invalid_count'].append(user_stats[1])
                    train_data = train_data.append(user_df)
                else:
                    # user cannot be enrolled into production due to threshold.
                    unenrolled_users.append(next_user)
                
                next_user = data['next']
            else:
                print('An error occurred while attempting to retrieve data from the API. Invalid User hash {}'.format(next_user))
                url_error += 1

# %%
# List of enrolled and unenrolled Users
print('Enrolled users are \n{}'.format(stats['user']))
print('\nUnenrolled users are \n{}'.format(unenrolled_users))
# Out:
# Enrolled users are
# ['user_4a438fdede4e11e9b986acde48001122.json', 'user_4a45245cde4e11e9b51bacde48001122.json', 'user_4a4558dcde4e11e9bbfaacde48001122.json', 'user_4a45bafade4e11e99e37acde48001122.json', 'user_4a45f03ade4e11e9922cacde48001122.json', 'user_4a4626c2de4e11e98c17acde48001122.json', 'user_4a466e5cde4e11e98e06acde48001122.json', 'user_4a46a7a8de4e11e99efeacde48001122.json', 'user_4a46debede4e11e996d6acde48001122.json', 'user_4a47153ade4e11e9a04eacde48001122.json', 'user_4a474bf6de4e11e980dbacde48001122.json', 'user_4a47885ade4e11e98c41acde48001122.json', 'user_4a482be8de4e11e9a2a2acde48001122.json', 'user_4a486266de4e11e98893acde48001122.json', 'user_4a4898e4de4e11e98573acde48001122.json', 'user_4a4905d8de4e11e99a50acde48001122.json', 'user_4a493c4ade4e11e99e33acde48001122.json', 'user_4a497764de4e11e9bc80acde48001122.json', 'user_4a49ae0ade4e11e9b2d3acde48001122.json', 'user_4a49e492de4e11e98206acde48001122.json', 'user_4a4a1b1ade4e11e9a868acde48001122.json', 'user_4a4a518cde4e11e99ae3acde48001122.json', 'user_4a4a8802de4e11e9a447acde48001122.json', 'user_4a4abe80de4e11e9963bacde48001122.json', 'user_4a4af4fede4e11e9b4c8acde48001122.json', 'user_4a4b2b86de4e11e99e25acde48001122.json', 'user_4a4b6358de4e11e9b361acde48001122.json', 'user_4a4b99d8de4e11e9ab53acde48001122.json', 'user_4a4bd05ede4e11e987bfacde48001122.json', 'user_4a4c06f0de4e11e997dfacde48001122.json', 'user_4a4c3d6ede4e11e98e3bacde48001122.json', 'user_4a4c73e2de4e11e98b63acde48001122.json', 'user_4a4ce17ede4e11e9a181acde48001122.json', 'user_4a4d17f4de4e11e9bdbaacde48001122.json', 'user_4a4d4e70de4e11e9a835acde48001122.json']
#
# Unenrolled users are
# ['user_4a4587d0de4e11e9857aacde48001122.json', 'user_4a47beecde4e11e9aea4acde48001122.json', 'user_4a47f568de4e11e98afcacde48001122.json', 'user_4a48cf62de4e11e9a654acde48001122.json', 'user_4a4cab0ade4e11e99c31acde48001122.json']

# %% [markdown]
# ## Model architecture and Training
# The model used here is a simple feed forward 3 layer neural network. The final layer of the model is a softmax that outputs the probability distribution over all the enrolled users.
# While more complex models like LSTM are better suited for the task, this model forms an appropriate baseline since it is one of the most simple architecture with basic feature extraction and engineering.

# %%
from keras.models import Sequential
from keras.layers import Dense
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
# from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.utils import shuffle
from keras import callbacks

# %%
no_classes = int(train_data.user_id.nunique())
train_data = shuffle(train_data)
X_train = train_data.iloc[:,1:-1]
Y_train = train_data.iloc[:,-1]
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y_train)
encoded_Y = encoder.transform(Y_train)
mapping = dict(zip(range(len(encoder.classes_)), encoder.classes_))
mapping[-1] = 'invalid input'
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)
 
# define baseline model
def baseline_model(input_dims, hidden_units, no_classes):
    # create model
    model = Sequential()
    model.add(Dense(hidden_units[0], input_dim=input_dims, activation='relu'))
    model.add(Dense(hidden_units[1], activation='relu'))
    model.add(Dense(no_classes, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

model = baseline_model(no_features, [100, 50], no_classes)
print(model.summary())
checkpoint_filepath = os.path.join(os.getcwd(), 'checkpoint')
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
model.fit(X_train, dummy_y, epochs=100, batch_size=1024, validation_split=0.1, callbacks=[model_checkpoint_callback])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 100)               3800
# _________________________________________________________________
# dense_22 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_23 (Dense)             (None, 35)                1785
# =================================================================
# Total params: 10,635
# Trainable params: 10,635
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 16/16 [==============================] - 0s 9ms/step - loss: 3.5481 - accuracy: 0.0595 - val_loss: 3.5326 - val_accuracy: 0.0708
# Epoch 2/100
# 16/16 [==============================] - 0s 5ms/step - loss: 3.5214 - accuracy: 0.0640 - val_loss: 3.5086 - val_accuracy: 0.0616
# Epoch 3/100
# 16/16 [==============================] - 0s 5ms/step - loss: 3.4943 - accuracy: 0.0589 - val_loss: 3.4748 - val_accuracy: 0.0616
# Epoch 4/100
# 16/16 [==============================] - 0s 6ms/step - loss: 3.4528 - accuracy: 0.0616 - val_loss: 3.4216 - val_accuracy: 0.0621
# Epoch 5/100
# 16/16 [==============================] - 0s 5ms/step - loss: 3.3891 - accuracy: 0.0603 - val_loss: 3.3425 - val_accuracy: 0.0691
# Epoch 6/100
# 16/16 [==============================] - 0s 5ms/step - loss: 3.2994 - accuracy: 0.0822 - val_loss: 3.2398 - val_accuracy: 0.0941
# Epoch 7/100
# 16/16 [==============================] - 0s 6ms/step - loss: 3.1887 - accuracy: 0.1077 - val_loss: 3.1155 - val_accuracy: 0.1173
# Epoch 8/100
# 16/16 [==============================] - 0s 6ms/step - loss: 3.0597 - accuracy: 0.1256 - val_loss: 2.9780 - val_accuracy: 0.1458
# Epoch 9/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.9225 - accuracy: 0.1438 - val_loss: 2.8423 - val_accuracy: 0.1568
# Epoch 10/100
# 16/16 [==============================] - 0s 5ms/step - loss: 2.7933 - accuracy: 0.1632 - val_loss: 2.7195 - val_accuracy: 0.1777
# Epoch 11/100
# 16/16 [==============================] - 0s 6ms/step - loss: 2.6724 - accuracy: 0.1920 - val_loss: 2.6069 - val_accuracy: 0.2300
# Epoch 12/100
# 16/16 [==============================] - 0s 6ms/step - loss: 2.5647 - accuracy: 0.2242 - val_loss: 2.5084 - val_accuracy: 0.2120
# Epoch 13/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.4692 - accuracy: 0.2282 - val_loss: 2.4223 - val_accuracy: 0.2468
# Epoch 14/100
# 16/16 [==============================] - 0s 5ms/step - loss: 2.3864 - accuracy: 0.2473 - val_loss: 2.3441 - val_accuracy: 0.2735
# Epoch 15/100
# 16/16 [==============================] - 0s 5ms/step - loss: 2.3133 - accuracy: 0.2647 - val_loss: 2.2782 - val_accuracy: 0.2642
# Epoch 16/100
# 16/16 [==============================] - 0s 6ms/step - loss: 2.2460 - accuracy: 0.2794 - val_loss: 2.2139 - val_accuracy: 0.3043
# Epoch 17/100
# 16/16 [==============================] - 0s 4ms/step - loss: 2.1856 - accuracy: 0.2840 - val_loss: 2.1567 - val_accuracy: 0.2956
# Epoch 18/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.1281 - accuracy: 0.3111 - val_loss: 2.1053 - val_accuracy: 0.3264
# Epoch 19/100
# 16/16 [==============================] - 0s 5ms/step - loss: 2.0763 - accuracy: 0.3292 - val_loss: 2.0539 - val_accuracy: 0.3281
# Epoch 20/100
# 16/16 [==============================] - 0s 6ms/step - loss: 2.0280 - accuracy: 0.3331 - val_loss: 2.0095 - val_accuracy: 0.3432
# Epoch 21/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.9824 - accuracy: 0.3555 - val_loss: 1.9673 - val_accuracy: 0.3699
# Epoch 22/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.9423 - accuracy: 0.3637 - val_loss: 1.9224 - val_accuracy: 0.3566
# Epoch 23/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.9048 - accuracy: 0.3585 - val_loss: 1.9019 - val_accuracy: 0.3438
# Epoch 24/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.8704 - accuracy: 0.3659 - val_loss: 1.8568 - val_accuracy: 0.3786
# Epoch 25/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.8367 - accuracy: 0.3955 - val_loss: 1.8261 - val_accuracy: 0.3711
# Epoch 26/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.8076 - accuracy: 0.4073 - val_loss: 1.8024 - val_accuracy: 0.3943
# Epoch 27/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.7785 - accuracy: 0.3993 - val_loss: 1.7720 - val_accuracy: 0.3862
# Epoch 28/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.7538 - accuracy: 0.4061 - val_loss: 1.7442 - val_accuracy: 0.4100
# Epoch 29/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.7278 - accuracy: 0.4298 - val_loss: 1.7256 - val_accuracy: 0.4181
# Epoch 30/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.7043 - accuracy: 0.4286 - val_loss: 1.7001 - val_accuracy: 0.4245
# Epoch 31/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.6823 - accuracy: 0.4290 - val_loss: 1.6834 - val_accuracy: 0.4355
# Epoch 32/100
# 16/16 [==============================] - 0s 7ms/step - loss: 1.6618 - accuracy: 0.4341 - val_loss: 1.6570 - val_accuracy: 0.4396
# Epoch 33/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.6432 - accuracy: 0.4438 - val_loss: 1.6403 - val_accuracy: 0.4088
# Epoch 34/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.6287 - accuracy: 0.4381 - val_loss: 1.6259 - val_accuracy: 0.4181
# Epoch 35/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.6108 - accuracy: 0.4404 - val_loss: 1.6038 - val_accuracy: 0.4425
# Epoch 36/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.5919 - accuracy: 0.4385 - val_loss: 1.5905 - val_accuracy: 0.4344
# Epoch 37/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.5769 - accuracy: 0.4502 - val_loss: 1.5754 - val_accuracy: 0.4425
# Epoch 38/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.5609 - accuracy: 0.4576 - val_loss: 1.5612 - val_accuracy: 0.4570
# Epoch 39/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.5468 - accuracy: 0.4640 - val_loss: 1.5502 - val_accuracy: 0.4402
# Epoch 40/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.5324 - accuracy: 0.4676 - val_loss: 1.5238 - val_accuracy: 0.4559
# Epoch 41/100
# 16/16 [==============================] - 0s 7ms/step - loss: 1.5193 - accuracy: 0.4604 - val_loss: 1.5214 - val_accuracy: 0.4512
# Epoch 42/100
# 16/16 [==============================] - 0s 7ms/step - loss: 1.5080 - accuracy: 0.4643 - val_loss: 1.5106 - val_accuracy: 0.4501
# Epoch 43/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.4975 - accuracy: 0.4660 - val_loss: 1.4986 - val_accuracy: 0.4611
# Epoch 44/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.4847 - accuracy: 0.4792 - val_loss: 1.4848 - val_accuracy: 0.4797
# Epoch 45/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.4748 - accuracy: 0.4758 - val_loss: 1.4724 - val_accuracy: 0.4611
# Epoch 46/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.4674 - accuracy: 0.4782 - val_loss: 1.4577 - val_accuracy: 0.4727
# Epoch 47/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.4579 - accuracy: 0.4709 - val_loss: 1.4507 - val_accuracy: 0.4657
# Epoch 48/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.4484 - accuracy: 0.4813 - val_loss: 1.4393 - val_accuracy: 0.4803
# Epoch 49/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.4402 - accuracy: 0.4797 - val_loss: 1.4388 - val_accuracy: 0.4739
# Epoch 50/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.4294 - accuracy: 0.4862 - val_loss: 1.4337 - val_accuracy: 0.4803
# Epoch 51/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.4251 - accuracy: 0.4799 - val_loss: 1.4213 - val_accuracy: 0.4739
# Epoch 52/100
# 16/16 [==============================] - 0s 7ms/step - loss: 1.4146 - accuracy: 0.4844 - val_loss: 1.4096 - val_accuracy: 0.4739
# Epoch 53/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.4071 - accuracy: 0.4850 - val_loss: 1.3968 - val_accuracy: 0.4861
# Epoch 54/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3999 - accuracy: 0.4909 - val_loss: 1.3915 - val_accuracy: 0.4785
# Epoch 55/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3941 - accuracy: 0.4929 - val_loss: 1.3879 - val_accuracy: 0.4878
# Epoch 56/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3907 - accuracy: 0.4879 - val_loss: 1.3985 - val_accuracy: 0.4727
# Epoch 57/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3845 - accuracy: 0.4834 - val_loss: 1.3760 - val_accuracy: 0.4861
# Epoch 58/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3766 - accuracy: 0.4852 - val_loss: 1.3673 - val_accuracy: 0.4878
# Epoch 59/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.3685 - accuracy: 0.4995 - val_loss: 1.3574 - val_accuracy: 0.4901
# Epoch 60/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.3609 - accuracy: 0.4995 - val_loss: 1.3531 - val_accuracy: 0.4988
# Epoch 61/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.3538 - accuracy: 0.4985 - val_loss: 1.3474 - val_accuracy: 0.4861
# Epoch 62/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.3496 - accuracy: 0.4972 - val_loss: 1.3390 - val_accuracy: 0.5017
# Epoch 63/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.3428 - accuracy: 0.5024 - val_loss: 1.3420 - val_accuracy: 0.4977
# Epoch 64/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.3386 - accuracy: 0.5040 - val_loss: 1.3476 - val_accuracy: 0.5023
# Epoch 65/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3362 - accuracy: 0.5029 - val_loss: 1.3373 - val_accuracy: 0.5058
# Epoch 66/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.3324 - accuracy: 0.5047 - val_loss: 1.3229 - val_accuracy: 0.5029
# Epoch 67/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.3271 - accuracy: 0.5036 - val_loss: 1.3124 - val_accuracy: 0.4994
# Epoch 68/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3224 - accuracy: 0.4969 - val_loss: 1.3141 - val_accuracy: 0.4994
# Epoch 69/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.3224 - accuracy: 0.5016 - val_loss: 1.3114 - val_accuracy: 0.5151
# Epoch 70/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3172 - accuracy: 0.5055 - val_loss: 1.3044 - val_accuracy: 0.4959
# Epoch 71/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.3103 - accuracy: 0.5029 - val_loss: 1.3079 - val_accuracy: 0.4942
# Epoch 72/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.3129 - accuracy: 0.5084 - val_loss: 1.2987 - val_accuracy: 0.5174
# Epoch 73/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.3091 - accuracy: 0.5158 - val_loss: 1.3001 - val_accuracy: 0.5134
# Epoch 74/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.3035 - accuracy: 0.5075 - val_loss: 1.2917 - val_accuracy: 0.5128
# Epoch 75/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2980 - accuracy: 0.5096 - val_loss: 1.2919 - val_accuracy: 0.5087
# Epoch 76/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2925 - accuracy: 0.5053 - val_loss: 1.2978 - val_accuracy: 0.5017
# Epoch 77/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2898 - accuracy: 0.5215 - val_loss: 1.2875 - val_accuracy: 0.4971
# Epoch 78/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2893 - accuracy: 0.5184 - val_loss: 1.2857 - val_accuracy: 0.5046
# Epoch 79/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2916 - accuracy: 0.5081 - val_loss: 1.2836 - val_accuracy: 0.5075
# Epoch 80/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2818 - accuracy: 0.5167 - val_loss: 1.2770 - val_accuracy: 0.5139
# Epoch 81/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2761 - accuracy: 0.5208 - val_loss: 1.2726 - val_accuracy: 0.5023
# Epoch 82/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2775 - accuracy: 0.5208 - val_loss: 1.2672 - val_accuracy: 0.5128
# Epoch 83/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.2726 - accuracy: 0.5171 - val_loss: 1.2589 - val_accuracy: 0.5197
# Epoch 84/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2677 - accuracy: 0.5208 - val_loss: 1.2623 - val_accuracy: 0.5151
# Epoch 85/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2660 - accuracy: 0.5225 - val_loss: 1.2550 - val_accuracy: 0.5197
# Epoch 86/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2642 - accuracy: 0.5221 - val_loss: 1.2547 - val_accuracy: 0.5099
# Epoch 87/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2611 - accuracy: 0.5260 - val_loss: 1.2532 - val_accuracy: 0.5105
# Epoch 88/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2629 - accuracy: 0.5217 - val_loss: 1.2555 - val_accuracy: 0.5110
# Epoch 89/100
# 16/16 [==============================] - 0s 6ms/step - loss: 1.2595 - accuracy: 0.5234 - val_loss: 1.2551 - val_accuracy: 0.5232
# Epoch 90/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2585 - accuracy: 0.5208 - val_loss: 1.2507 - val_accuracy: 0.5308
# Epoch 91/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2580 - accuracy: 0.5217 - val_loss: 1.2466 - val_accuracy: 0.5273
# Epoch 92/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2522 - accuracy: 0.5297 - val_loss: 1.2473 - val_accuracy: 0.5221
# Epoch 93/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2480 - accuracy: 0.5273 - val_loss: 1.2359 - val_accuracy: 0.5267
# Epoch 94/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2489 - accuracy: 0.5284 - val_loss: 1.2375 - val_accuracy: 0.5186
# Epoch 95/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2447 - accuracy: 0.5277 - val_loss: 1.2379 - val_accuracy: 0.5209
# Epoch 96/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2446 - accuracy: 0.5300 - val_loss: 1.2433 - val_accuracy: 0.5110
# Epoch 97/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2494 - accuracy: 0.5221 - val_loss: 1.2437 - val_accuracy: 0.5029
# Epoch 98/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2442 - accuracy: 0.5301 - val_loss: 1.2497 - val_accuracy: 0.5279
# Epoch 99/100
# 16/16 [==============================] - 0s 4ms/step - loss: 1.2439 - accuracy: 0.5330 - val_loss: 1.2352 - val_accuracy: 0.5238
# Epoch 100/100
# 16/16 [==============================] - 0s 5ms/step - loss: 1.2381 - accuracy: 0.5276 - val_loss: 1.2314 - val_accuracy: 0.5238

# %%
model.load_weights(checkpoint_filepath)

# %%
# User performance report
train_pred_class = np.argmax(model.predict(X_train), axis=-1)
perf_df = pd.DataFrame({'y_true' : encoded_Y, 'y_pred': train_pred_class})
perf_df['outcome'] = perf_df.y_true == perf_df.y_pred
perf_df = perf_df.groupby('y_true')['outcome'].agg(['sum', 'count'])
perf_df.reset_index(inplace = True)
perf_df['acc'] = perf_df['sum']/perf_df['count']
perf_df.acc.describe()
# Out:
# count    35.000000
# mean      0.500673
# std       0.274467
# min       0.000000
# 25%       0.233750
# 50%       0.587121
# 75%       0.703155
# max       0.916493
# Name: acc, dtype: float64

# %%
# Test Data
test_url = 'https://challenges.unify.id/v1/mle/sample_test.json'
with request.urlopen(test_url) as response:
    if response.getcode() == 200:
        source = response.read()
        data = json.loads(source)
        test_df, user_stats, invalid_idx = validateFeaturizeData(data['attempts'], 'test', col_names[:-1])

final_idx = []
for i, idx in enumerate(invalid_idx):
    final_idx.append(idx-i)

# %%
# predicting for the test data
X_test = test_df.iloc[:,1:-1]
# pred_class = model.predict_classes(X_test)
pred_class = np.argmax(model.predict(X_test), axis=-1)
# print(pred_class.shape)
pred_class = np.insert(pred_class, final_idx , -1)
pred_user = []
for user in pred_class:
    pred_user.append(mapping[user])

# %%
json.dumps(list(pred_user))
# Out:
# '["user_4a4af4fede4e11e9b4c8acde48001122.json", "user_4a4b6358de4e11e9b361acde48001122.json", "user_4a4d4e70de4e11e9a835acde48001122.json", "user_4a49e492de4e11e98206acde48001122.json", "user_4a47885ade4e11e98c41acde48001122.json", "user_4a47885ade4e11e98c41acde48001122.json", "user_4a482be8de4e11e9a2a2acde48001122.json", "user_4a49e492de4e11e98206acde48001122.json", "user_4a46debede4e11e996d6acde48001122.json", "invalid input", "user_4a46a7a8de4e11e99efeacde48001122.json", "user_4a4c06f0de4e11e997dfacde48001122.json", "user_4a4abe80de4e11e9963bacde48001122.json", "user_4a486266de4e11e98893acde48001122.json", "invalid input", "user_4a4a518cde4e11e99ae3acde48001122.json", "user_4a4626c2de4e11e98c17acde48001122.json", "invalid input", "user_4a49e492de4e11e98206acde48001122.json", "user_4a4d4e70de4e11e9a835acde48001122.json", "user_4a4a518cde4e11e99ae3acde48001122.json", "user_4a49e492de4e11e98206acde48001122.json", "user_4a47885ade4e11e98c41acde48001122.json", "user_4a49ae0ade4e11e9b2d3acde48001122.json", "invalid input", "user_4a49ae0ade4e11e9b2d3acde48001122.json", "user_4a4d17f4de4e11e9bdbaacde48001122.json", "user_4a4c06f0de4e11e997dfacde48001122.json", "invalid input", "user_4a49e492de4e11e98206acde48001122.json", "user_4a4558dcde4e11e9bbfaacde48001122.json", "user_4a4c06f0de4e11e997dfacde48001122.json", "user_4a45f03ade4e11e9922cacde48001122.json", "user_4a49e492de4e11e98206acde48001122.json", "user_4a4abe80de4e11e9963bacde48001122.json", "user_4a4ce17ede4e11e9a181acde48001122.json", "invalid input", "user_4a4ce17ede4e11e9a181acde48001122.json", "invalid input", "user_4a4af4fede4e11e9b4c8acde48001122.json", "user_4a4c73e2de4e11e98b63acde48001122.json", "user_4a46a7a8de4e11e99efeacde48001122.json", "invalid input", "user_4a486266de4e11e98893acde48001122.json", "user_4a4b99d8de4e11e9ab53acde48001122.json", "invalid input", "user_4a47885ade4e11e98c41acde48001122.json", "user_4a4b6358de4e11e9b361acde48001122.json", "user_4a4558dcde4e11e9bbfaacde48001122.json", "user_4a49e492de4e11e98206acde48001122.json", "user_4a4d17f4de4e11e9bdbaacde48001122.json", "user_4a47885ade4e11e98c41acde48001122.json", "user_4a493c4ade4e11e99e33acde48001122.json", "user_4a4c3d6ede4e11e98e3bacde48001122.json", "user_4a4626c2de4e11e98c17acde48001122.json", "user_4a45245cde4e11e9b51bacde48001122.json", "user_4a4af4fede4e11e9b4c8acde48001122.json", "user_4a4a8802de4e11e9a447acde48001122.json", "user_4a4b6358de4e11e9b361acde48001122.json", "invalid input", "invalid input", "user_4a493c4ade4e11e99e33acde48001122.json", "user_4a47153ade4e11e9a04eacde48001122.json", "invalid input", "user_4a49e492de4e11e98206acde48001122.json", "user_4a4a518cde4e11e99ae3acde48001122.json", "user_4a46a7a8de4e11e99efeacde48001122.json", "user_4a47885ade4e11e98c41acde48001122.json", "user_4a49e492de4e11e98206acde48001122.json", "invalid input", "user_4a45245cde4e11e9b51bacde48001122.json", "user_4a49e492de4e11e98206acde48001122.json", "invalid input", "user_4a482be8de4e11e9a2a2acde48001122.json", "user_4a4558dcde4e11e9bbfaacde48001122.json", "user_4a4abe80de4e11e9963bacde48001122.json", "invalid input", "user_4a49e492de4e11e98206acde48001122.json", "user_4a486266de4e11e98893acde48001122.json", "user_4a4b2b86de4e11e99e25acde48001122.json", "user_4a4d4e70de4e11e9a835acde48001122.json", "user_4a4ce17ede4e11e9a181acde48001122.json", "user_4a47885ade4e11e98c41acde48001122.json", "invalid input", "user_4a486266de4e11e98893acde48001122.json", "user_4a4abe80de4e11e9963bacde48001122.json", "invalid input", "user_4a4a8802de4e11e9a447acde48001122.json", "user_4a4b2b86de4e11e99e25acde48001122.json", "user_4a47153ade4e11e9a04eacde48001122.json", "user_4a4c06f0de4e11e997dfacde48001122.json", "user_4a493c4ade4e11e99e33acde48001122.json", "invalid input", "user_4a493c4ade4e11e99e33acde48001122.json", "user_4a47885ade4e11e98c41acde48001122.json", "user_4a4b6358de4e11e9b361acde48001122.json", "user_4a493c4ade4e11e99e33acde48001122.json", "user_4a49e492de4e11e98206acde48001122.json", "invalid inp ...
